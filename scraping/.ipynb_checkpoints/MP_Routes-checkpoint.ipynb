# %% [markdown]
# <a href="https://colab.research.google.com/github/ColeDCrawford/mp-scrape/blob/master/MP_Routes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup as bs
import requests
import re

import pprint
pp = pprint.PrettyPrinter(indent=2)

idPattern = re.compile("^[0-9]{1,10}$")
uniqueRouteIds = set()

import pandas as pd
import time

import csv

# from google.colab import files
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
apikey = ''
all_routes = []
# pre = '/content/gdrive/My Drive/Mountain Project Scrape/'
pre = ""

route_location_ids = {}
with open(f"{pre}route_loc_ids.csv") as read_obj:
  csv_dict_reader = csv.DictReader(read_obj)
  for row in csv_dict_reader:
    route_location_ids[int(row['routeId'])] = int(row['locationId'])

with open(f"{pre}route_loc_ids-after-indiana.csv") as read_obj:
  csv_dict_reader = csv.DictReader(read_obj)
  for row in csv_dict_reader:
    route_location_ids[int(row['routeId'])] = int(row['locationId'])

# %%
def get_routes(ids, pause=5):
  time.sleep(pause)
  str_ids = ','.join(str(x) for x in ids)
  params = {
      'key': apikey,
      'routeIds': str_ids
  }
  r = requests.get('https://www.mountainproject.com/data/get-routes', params=params)
  if(r.json()['success'] == 1):
    routes = r.json()['routes']
    # enhance with location ID
    for route in routes:
      locationId = route_location_ids[route['id']]
      route['locationId'] = locationId
    return routes
  else:
    print("Error")
    print(r.json())
    return False

# %%
routeIds = list(route_location_ids.keys())
print(f"Total route IDs: {len(routeIds)}")

def divide_chunks(l, n): 
  for i in range(0, len(l), n):  
    yield l[i:i + n]

finished = set()
with open(f"{pre}route_data_v2.csv") as read_obj:
  csv_dict_reader = csv.DictReader(read_obj)
  for row in csv_dict_reader:
    finished.add(int(row['id']))
with open(f"{pre}route_data_v1.csv") as read_obj:
  csv_dict_reader = csv.DictReader(read_obj)
  for row in csv_dict_reader:
    finished.add(int(row['id']))
with open(f"{pre}route_data_v3.csv") as read_obj:
  csv_dict_reader = csv.DictReader(read_obj)
  for row in csv_dict_reader:
    finished.add(int(row['id']))
with open(f"{pre}route_data_v4.csv") as read_obj:
  csv_dict_reader = csv.DictReader(read_obj)
  for row in csv_dict_reader:
    finished.add(int(row['id']))
with open(f"{pre}route_data_v5.csv") as read_obj:
  csv_dict_reader = csv.DictReader(read_obj)
  for row in csv_dict_reader:
    finished.add(int(row['id']))
with open(f"{pre}route_data_v6.csv") as read_obj:
  csv_dict_reader = csv.DictReader(read_obj)
  for row in csv_dict_reader:
    finished.add(int(row['id']))
print(f"Total finished: {len(finished)}")

toProcess = []
for i in routeIds:
  if(i not in finished):
    toProcess.append(i)

print(f"To process: {len(toProcess)}")
# Out:
# Total route IDs: 228287
# Total finished: 228287
# To process: 0

# %%
chunked = list(divide_chunks(toProcess, 200))
for num, chunk in enumerate(chunked):
  # print(chunk)
  routes = get_routes(chunk)
  last = routes[-1]['id']
  all_routes.extend(routes)
  if((num % 10 == 0) or (num == len(chunked)-1)):
    # write
    df = pd.DataFrame(all_routes)
    df.to_csv(f"{pre}route_data_v6.csv", index=False)
    print(f"Previous runs: {len(finished)} | As of last run: {num*200} | Remaining: {len(toProcess) - (num*200)}")
# Out:
# Previous runs: 216000 | As of last run: 0 | Remaining: 12287
# Previous runs: 216000 | As of last run: 2000 | Remaining: 10287
# Previous runs: 216000 | As of last run: 4000 | Remaining: 8287
# Previous runs: 216000 | As of last run: 6000 | Remaining: 6287
# Previous runs: 216000 | As of last run: 8000 | Remaining: 4287
# Previous runs: 216000 | As of last run: 10000 | Remaining: 2287
# Previous runs: 216000 | As of last run: 12000 | Remaining: 287
# Previous runs: 216000 | As of last run: 12200 | Remaining: 87

# %%
print(len(all_routes))
# Out:
# 12287

# %%
joined = []
for i in range(1,6):
    print(i)
    with open(f"route_data_v{i}.csv") as read_obj:
      csv_dict_reader = csv.DictReader(read_obj)
      for row in csv_dict_reader:
           joined.append(row)
# Out:
# 1
# 2
# 3
# 4
# 5
# [{'id': '105923687', 'name': 'Second Cup', 'type': 'Sport', 'rating': '5.11a', 'stars': '3.3', 'starVotes': '6', 'pitches': '1', 'location': "['Alabama', 'Griffin Falls']", 'url': 'https://www.mountainproject.com/route/105923687/second-cup', 'imgSqSmall': '', 'imgSmall': '', 'imgSmallMed': '', 'imgMedium': '', 'longitude': '-85.9237', 'latitude': '34.2876', 'locationId': '105923472'}, {'id': '105923692', 'name': 'Just Right', 'type': 'Sport', 'rating': '5.11a', 'stars': '4.0', 'starVotes': '2', 'pitches': '1', 'location': "['Alabama', 'Griffin Falls']", 'url': 'https://www.mountainproject.com/route/105923692/just-right', 'imgSqSmall': '', 'imgSmall': '', 'imgSmallMed': '', 'imgMedium': '', 'longitude': '-85.9237', 'latitude': '34.2876', 'locationId': '105923472'}, {'id': '105923698', 'name': 'Knife Crack', 'type': 'Trad', 'rating': '5.9+', 'stars': '4.7', 'starVotes': '44', 'pitches': '1', 'location': "['Alabama', 'Griffin Falls']", 'url': 'https://www.mountainproject.com/route/105923698/knife-crack', 'imgSqSmall': 'https://cdn2.apstatic.com/photos/climb/112060744_sqsmall_1494319135.jpg', 'imgSmall': 'https://cdn2.apstatic.com/photos/climb/112060744_small_1494319135.jpg', 'imgSmallMed': 'https://cdn2.apstatic.com/photos/climb/112060744_smallMed_1494319135.jpg', 'imgMedium': 'https://cdn2.apstatic.com/photos/climb/112060744_medium_1494319135.jpg', 'longitude': '-85.9237', 'latitude': '34.2876', 'locationId': '105923472'}, {'id': '105923704', 'name': 'Thin Flakes', 'type': 'Trad', 'rating': '5.9', 'stars': '2.8', 'starVotes': '9', 'pitches': '1', 'location': "['Alabama', 'Griffin Falls']", 'url': 'https://www.mountainproject.com/route/105923704/thin-flakes', 'imgSqSmall': 'https://cdn2.apstatic.com/photos/climb/112061009_sqsmall_1494319181.jpg', 'imgSmall': 'https://cdn2.apstatic.com/photos/climb/112061009_small_1494319181.jpg', 'imgSmallMed': 'https://cdn2.apstatic.com/photos/climb/112061009_smallMed_1494319181.jpg', 'imgMedium': 'https://cdn2.apstatic.com/photos/climb/112061009_medium_1494319181.jpg', 'longitude': '-85.9237', 'latitude': '34.2876', 'locationId': '105923472'}, {'id': '105923708', 'name': 'Whetstone', 'type': 'Trad', 'rating': '5.9+ PG13', 'stars': '3.8', 'starVotes': '9', 'pitches': '1', 'location': "['Alabama', 'Griffin Falls']", 'url': 'https://www.mountainproject.com/route/105923708/whetstone', 'imgSqSmall': 'https://cdn2.apstatic.com/photos/climb/106170752_sqsmall_1494085198.jpg', 'imgSmall': 'https://cdn2.apstatic.com/photos/climb/106170752_small_1494085198.jpg', 'imgSmallMed': 'https://cdn2.apstatic.com/photos/climb/106170752_smallMed_1494085198.jpg', 'imgMedium': 'https://cdn2.apstatic.com/photos/climb/106170752_medium_1494085198.jpg', 'longitude': '-85.9237', 'latitude': '34.2876', 'locationId': '105923472'}]

# %%
df_export = pd.DataFrame(joined)
df_export.to_csv("mp_routes_joined.csv", index=False)
